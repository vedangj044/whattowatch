# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mov_df = pd.read_csv(r'D:\Udemy Python and ML\Datasets\Movie\wiki_movie_plots_deduped.csv')

# %%
mov_df
# Out:
#        Release Year                             Title Origin/Ethnicity  \
# 0              1901            Kansas Saloon Smashers         American
# 1              1901     Love by the Light of the Moon         American
# 2              1901           The Martyred Presidents         American
# 3              1901  Terrible Teddy, the Grizzly King         American
# 4              1902            Jack and the Beanstalk         American
# ...             ...                               ...              ...
# 34881          2014                 The Water Diviner          Turkish
# 34882          2017                Çalgı Çengi İkimiz          Turkish
# 34883          2017                      Olanlar Oldu          Turkish
# 34884          2017                  Non-Transferable          Turkish
# 34885          2017                İstanbul Kırmızısı          Turkish
#
#                                  Director  \
# 0                                 Unknown
# ...

# %%
mov_df.describe()
# Out:
#        Release Year
# count  34886.000000
# mean    1981.314252
# std       27.815174
# min     1901.000000
# 25%     1957.000000
# 50%     1988.000000
# 75%     2007.000000
# max     2017.000000

# %%
# Plot for Movies released per year
mov_df.hist(bins = 116, figsize = (10,8), grid= True, color = '#12ccf2')
plt.savefig('foo1.pdf')
plt.savefig('foo.png')

# %%
mov_df['Genre']
# Out:
# 0                unknown
# 1                unknown
# 2                unknown
# 3                unknown
# 4                unknown
#               ...
# 34881            unknown
# 34882             comedy
# 34883             comedy
# 34884    romantic comedy
# 34885           romantic
# Name: Genre, Length: 34886, dtype: object

# %%
mov_df['Genre'].describe()
# Out:
# count       34886
# unique       2265
# top       unknown
# freq         6083
# Name: Genre, dtype: object

# %%
mov_df['Genre'].value_counts()
# Out:
# unknown                          6083
# drama                            5964
# comedy                           4379
# horror                           1167
# action                           1098
#                                  ...
# action-adventure, sci-fi            1
# mocatsu                             1
# family, superhero                   1
# action / adventure / thriller       1
# animation, musical, comedy          1
# Name: Genre, Length: 2265, dtype: int64

# %%
# Dropping the unknown categories
mov_df2 = mov_df[~mov_df['Genre'].isin(['unknown'])]

# %%
mov_df2
# Out:
#        Release Year                                              Title  \
# 6              1903                            The Great Train Robbery
# 7              1904                                    The Suburbanite
# 10             1906                           Dream of a Rarebit Fiend
# 11             1906  From Leadville to Aspen: A Hold-Up in the Rockies
# 12             1906                                Kathleen Mavourneen
# ...             ...                                                ...
# 34877          2013                                    Particle (film)
# 34882          2017                                 Çalgı Çengi İkimiz
# 34883          2017                                       Olanlar Oldu
# 34884          2017                                   Non-Transferable
# 34885          2017                                 İstanbul Kırmızısı
#
#       Origin/Ethnicity                                  Director  \
# ...

# %%
mov_df2['Genre'].value_counts()
# Out:
# drama                                             5964
# comedy                                            4379
# horror                                            1167
# action                                            1098
# thriller                                           966
#                                                   ...
# drama, romance, comedy, musical                      1
# drama co-produced with the national film board       1
# sci-fi, 3-d                                          1
# period film                                          1
# animation, musical, comedy                           1
# Name: Genre, Length: 2264, dtype: int64

# %%
plotter = mov_df2['Genre'].value_counts()

# %%
plotter.head(30)
# Out:
# drama              5964
# comedy             4379
# horror             1167
# action             1098
# thriller            966
# romance             923
# western             865
# crime               568
# adventure           526
# musical             467
# crime drama         464
# romantic comedy     461
# science fiction     418
# film noir           345
# mystery             310
# war                 273
# animation           264
# comedy, drama       236
# sci-fi              221
# family              217
# fantasy             204
# animated            195
# musical comedy      154
# comedy-drama        137
# biography           136
# anime               112
# suspense            104
# comedy drama        103
# romantic drama      103
# animated short       91
# Name: Genre, dtype: int64

# %%
# Cumulating mixed categories
mov_df2_oth = 0
for i in plotter: 
    if(i<=80):
         mov_df2_oth = mov_df2_oth + i
mov_df2_oth
# Out:
# 7164

# %%
type(plotter)
# Out:
# pandas.core.series.Series

# %%
val_d = pd.DataFrame(plotter)

# %%
val_d
# Out:
#                                                 Genre
# drama                                            5964
# comedy                                           4379
# horror                                           1167
# action                                           1098
# thriller                                          966
# ...                                               ...
# drama, romance, comedy, musical                     1
# drama co-produced with the national film board      1
# sci-fi, 3-d                                         1
# period film                                         1
# animation, musical, comedy                          1
#
# [2264 rows x 1 columns]

# %%
new_row = {"Genre": mov_df2_oth }
type(val_d)
# Out:
# pandas.core.frame.DataFrame

# %%
mov_df2_df = pd.DataFrame(data = mov_df2_oth, index = ['others'], columns = ['Genre'])

# %%
mov_df2_df
# Out:
#         Genre
# others   7164

# %%
mov_df3=val_d.append(mov_df2_df)

# %%
mov_df3
# Out:
#                                                 Genre
# drama                                            5964
# comedy                                           4379
# horror                                           1167
# action                                           1098
# thriller                                          966
# ...                                               ...
# drama co-produced with the national film board      1
# sci-fi, 3-d                                         1
# period film                                         1
# animation, musical, comedy                          1
# others                                           7164
#
# [2265 rows x 1 columns]

# %%
mov_df3.drop(mov_df3[mov_df3['Genre']<80].index,inplace = True)

# %%
mov_df3.rename(columns = {'Genre':'Genre Count'}, inplace = True)

# %%
# Plot for Category-wise movie count
mov_df3.plot(kind='bar', figsize = (15,15),grid= True, color = '#12ccf2' )
plt.savefig('foo2.pdf')
plt.savefig('foo2_1.png')

# %% [markdown]
# # Cleaning data from here on out

# %%
# New attribute generation for simplification of categories
mov_df2['Count']=1
mov_df2[['Genre','Count']].groupby(['Genre'], as_index=False).count().shape[0]


mov_df2['GenreCorrected'] =mov_df2['Genre'] 
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.strip()
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' - ', '|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' / ', '|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('/', '|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' & ', '|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(', ', '|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('; ', '|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('bio-pic', 'biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biopic', 'biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biographical', 'biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biodrama', 'biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('bio-drama', 'biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biographic', 'biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' \(film genre\)', '')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('animated','animation')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('anime','animation')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('children\'s','children')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('comedey','comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\[not in citation given\]','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' set 4,000 years ago in the canadian arctic','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('historical','history')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('romantic','romance')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('3-d','animation')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('3d','animation')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('viacom 18 motion pictures','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('sci-fi','science_fiction')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('ttriller','thriller')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('.','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('based on radio serial','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' on the early years of hitler','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('sci fi','science_fiction')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('science fiction','science_fiction')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' (30min)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('16 mm film','short')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\[140\]','drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\[144\]','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' for ','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('adventures','adventure')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('kung fu','martial_arts')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('kung-fu','martial_arts')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('martial arts','martial_arts')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('world war ii','war')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('world war i','war')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biography about montreal canadiens star|maurice richard','biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('bholenath mov_df2|cinekorn entertainment','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' \(volleyball\)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('spy film','spy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('anthology film','anthology')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biography fim','biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('avant-garde','avant_garde')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biker film','biker')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('buddy cop','buddy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('buddy film','buddy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('comedy 2-reeler','comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('films','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('film','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biography of pioneering american photographer eadweard muybridge','biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('british-german co-production','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('bruceploitation','martial_arts')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('comedy-drama adaptation of the mordecai richler novel','comedy-drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('mov_df2 by the mob\|knkspl','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('mov_df2','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('movie','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('coming of age','coming_of_age')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('coming-of-age','coming_of_age')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('drama about child soldiers','drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('(( based).+)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('(( co-produced).+)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('(( adapted).+)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('(( about).+)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('musical b','musical')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('animationchildren','animation|children')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' period','period')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('drama loosely','drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' \(aquatics|swimming\)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' \(aquatics|swimming\)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace("yogesh dattatraya gosavi's directorial debut \[9\]",'')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace("war-time","war")
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace("wartime","war")
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace("ww1","war")
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('unknown','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace("wwii","war")
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('psychological','psycho')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('rom-coms','romance')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('true crime','crime')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\|007','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('slice of life','slice_of_life')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('computer animation','animation')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('gun fu','martial_arts')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('j-horror','horror')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' \(shogi|chess\)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('afghan war drama','war drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\|6 separate stories','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' \(30min\)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' (road bicycle racing)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' v-cinema','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('tv miniseries','tv_miniseries')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\|docudrama','\|documentary|drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' in animation','|animation')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('((adaptation).+)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('((adaptated).+)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('((adapted).+)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('(( on ).+)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('american football','sports')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('dev\|nusrat jahan','sports')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('television miniseries','tv_miniseries')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' \(artistic\)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' \|direct-to-dvd','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('history dram','history drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('martial art','martial_arts')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('psycho thriller,','psycho thriller')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\|1 girl\|3 suitors','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' \(road bicycle racing\)','')
# Out:
# <ipython-input-26-3901e533bd5f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov_df2['Count']=1
# <ipython-input-26-3901e533bd5f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov_df2['GenreCorrected'] =mov_df2['Genre']
# <ipython-input-26-3901e533bd5f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
mov_df2
# Out:
#        Release Year                                              Title  \
# 6              1903                            The Great Train Robbery
# 7              1904                                    The Suburbanite
# 10             1906                           Dream of a Rarebit Fiend
# 11             1906  From Leadville to Aspen: A Hold-Up in the Rockies
# 12             1906                                Kathleen Mavourneen
# ...             ...                                                ...
# 34877          2013                                    Particle (film)
# 34882          2017                                 Çalgı Çengi İkimiz
# 34883          2017                                       Olanlar Oldu
# 34884          2017                                   Non-Transferable
# 34885          2017                                 İstanbul Kırmızısı
#
#       Origin/Ethnicity                                  Director  \
# ...

# %%
filterE = mov_df2['GenreCorrected']=="ero"
mov_df2.loc[filterE,'GenreCorrected']="adult"
filterE = mov_df2['GenreCorrected']=="music"
mov_df2.loc[filterE,'GenreCorrected']="musical"
filterE = mov_df2['GenreCorrected']=="-"
mov_df2.loc[filterE,'GenreCorrected']=''
filterE = mov_df2['GenreCorrected']=="comedy–drama"
mov_df2.loc[filterE,'GenreCorrected'] = "comedy|drama"
filterE = mov_df2['GenreCorrected']=="comedy–horror"
mov_df2.loc[filterE,'GenreCorrected'] = "comedy|horror"
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' ','|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(',','|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('-','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('actionadventure','action|adventure')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('actioncomedy','action|comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('actiondrama','action|drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('actionlove','action|love')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('actionmasala','action|masala')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('actionchildren','action|children')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('fantasychildren\|','fantasy|children')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('fantasycomedy','fantasy|comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('fantasyperiod','fantasy|period')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('cbctv_miniseries','tv_miniseries')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('dramacomedy','drama|comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('dramacomedysocial','drama|comedy|social')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('dramathriller','drama|thriller')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('comedydrama','comedy|drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('dramathriller','drama|thriller')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('comedyhorror','comedy|horror')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('sciencefiction','science_fiction')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('adventurecomedy','adventure|comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('animationdrama','animation|drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\|\|','|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('muslim','religious')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('thriler','thriller')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('crimethriller','crime|thriller')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('fantay','fantasy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('actionthriller','action|thriller')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('comedysocial','comedy|social')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('martialarts','martial_arts')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\|\(children\|poker\|karuta\)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('epichistory','epic|history')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('erotica','adult')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('erotic','adult')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('((\|produced\|).+)','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('chanbara','chambara')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('comedythriller','comedy|thriller')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biblical','religious')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biblical','religious')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('colour\|yellow\|productions\|eros\|international','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\|directtodvd','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('liveaction','live|action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('melodrama','drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('superheroes','superheroe')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('gangsterthriller','gangster|thriller')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('heistcomedy','comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('heist','action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('historic','history')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('historydisaster','history|disaster')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('warcomedy','war|comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('westerncomedy','western|comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('ancientcostume','costume')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('computeranimation','animation')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('dramatic','drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('familya','family')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('familya','family')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('dramedy','drama|comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('dramaa','drama')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('famil\|','family')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('superheroe','superhero')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('biogtaphy','biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('devotionalbiography','devotional|biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('docufiction','documentary|fiction')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('familydrama','family|drama')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('espionage','spy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('supeheroes','superhero')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('romancefiction','romance|fiction')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('horrorthriller','horror|thriller')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('suspensethriller','suspense|thriller')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('musicaliography','musical|biography')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('triller','thriller')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\|\(fiction\)','|fiction')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('romanceaction','romance|action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('romancecomedy','romance|comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('romancehorror','romance|horror')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('romcom','romance|comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('rom\|com','romance|comedy')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('satirical','satire')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('science_fictionchildren','science_fiction|children')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('homosexual','adult')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('sexual','adult')

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('mockumentary','documentary')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('periodic','period')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('romanctic','romantic')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('politics','political')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('samurai','martial_arts')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('tv_miniseries','series')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('serial','series')

filterE = mov_df2['GenreCorrected']=="musical–comedy"
mov_df2.loc[filterE,'GenreCorrected'] = "musical|comedy"

filterE = mov_df2['GenreCorrected']=="roman|porno"
mov_df2.loc[filterE,'GenreCorrected'] = "adult"


filterE = mov_df2['GenreCorrected']=="action—masala"
mov_df2.loc[filterE,'GenreCorrected'] = "action|masala"


filterE = mov_df2['GenreCorrected']=="horror–thriller"
mov_df2.loc[filterE,'GenreCorrected'] = "horror|thriller"

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('family','children')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('martial_arts','action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('horror','thriller')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('war','action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('adventure','action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('science_fiction','action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('western','action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('western','action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('noir','black')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('spy','action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('superhero','action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('social','')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('suspense','action')


filterE = mov_df2['GenreCorrected']=="drama|romance|adult|children"
mov_df2.loc[filterE,'GenreCorrected'] = "drama|romance|adult"

mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('\|–\|','|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.strip(to_strip='\|')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace('actionner','action')
mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.strip()
# Out:
# c:\users\admin\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-28-18bcde8465fb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov_df2['GenreCorrected']=mov_df2['GenreCorrected'].str.replace(' ','|')
# <ipython-input-28-18bcde8465fb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
mov_df2
# Out:
#        Release Year                                              Title  \
# 6              1903                            The Great Train Robbery
# 7              1904                                    The Suburbanite
# 10             1906                           Dream of a Rarebit Fiend
# 11             1906  From Leadville to Aspen: A Hold-Up in the Rockies
# 12             1906                                Kathleen Mavourneen
# ...             ...                                                ...
# 34877          2013                                    Particle (film)
# 34882          2017                                 Çalgı Çengi İkimiz
# 34883          2017                                       Olanlar Oldu
# 34884          2017                                   Non-Transferable
# 34885          2017                                 İstanbul Kırmızısı
#
#       Origin/Ethnicity                                  Director  \
# ...

# %%
moviesGenre = mov_df2[['GenreCorrected','Count']].groupby(['GenreCorrected']).count()
moviesGenre.to_csv('GenreCorrected.csv',sep=',')
mov_df2[['GenreCorrected','Count']].groupby(['GenreCorrected'], as_index=False).count().shape[0]
# Out:
# 1201

# %%
moviesGenre
# Out:
#                       Count
# GenreCorrected
#                         121
# 16 mm                     1
# action                 3790
# action|action           163
# action|action|action     21
# ...                     ...
# youth|music|drama         1
# youth|romance             1
# yuen|laikei               1
# zombie|comedy             2
# zombie|thriller           2
#
# [1201 rows x 1 columns]

# %%
mov_df2[['GenreCorrected','Count']].groupby(['GenreCorrected'],as_index=False).count().sort_values(['Count'], ascending=False).head(15)
# Out:
#       GenreCorrected  Count
# 517            drama   6107
# 360           comedy   4411
# 2             action   3790
# 1113        thriller   2163
# 965          romance    954
# 203        animation    601
# 974   romance|comedy    577
# 448            crime    573
# 388     comedy|drama    560
# 458      crime|drama    502
# 835          musical    471
# 301            black    345
# 855          mystery    310
# 990    romance|drama    262
# 323         children    256

# %%
mov_df2['GenreSplit']=mov_df2['GenreCorrected'].str.split('|')
mov_df2['GenreSplit']= mov_df2['GenreSplit'].apply(np.sort).apply(np.unique)
# Out:
# <ipython-input-33-df55dd9ef73e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov_df2['GenreSplit']=mov_df2['GenreCorrected'].str.split('|')
# <ipython-input-33-df55dd9ef73e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov_df2['GenreSplit']= mov_df2['GenreSplit'].apply(np.sort).apply(np.unique)

# %%
mov_df2['GenreSplit'][11]
# Out:
# array(['action', 'crime', 'short'], dtype='<U6')

# %%
mov_df2.head(15)
# Out:
#     Release Year                                              Title  \
# 6           1903                            The Great Train Robbery
# 7           1904                                    The Suburbanite
# 10          1906                           Dream of a Rarebit Fiend
# 11          1906  From Leadville to Aspen: A Hold-Up in the Rockies
# 12          1906                                Kathleen Mavourneen
# 13          1907                                       Daniel Boone
# 14          1907                    How Brown Saw the Baseball Game
# 15          1907                                       Laughing Gas
# 16          1908                           The Adventures of Dollie
# 17          1908                                    The Black Viper
# 18          1908                             A Calamitous Elopement
# 19          1908                               The Call of the Wild
# 20          1908                                  A Christmas Carol
# ...

# %%
genres_array = np.array([])

for i in range(0,mov_df2.shape[0]-1):
    if i in mov_df2['GenreSplit'].index :
        genres_array = np.concatenate((genres_array, mov_df2['GenreSplit'][i] ))
    
genres_array

# len(mov_df2)
# Out:
# array(['action', 'comedy', 'short', ..., 'drama', 'action', 'comedy'],
#       dtype='<U32')

# %%
mov_df2.shape[0]
# Out:
# 28803

# %%
genres = pd.DataFrame({'Genre':genres_array})

# %%
genres
# Out:
#          Genre
# 0       action
# 1       comedy
# 2        short
# 3       action
# 4        crime
# ...        ...
# 33237  romance
# 33238    drama
# 33239    drama
# 33240   action
# 33241   comedy
#
# [33242 rows x 1 columns]

# %%
genres['Count']=1
genres[['Genre','Count']].groupby(['Genre'], as_index=False).sum().sort_values(['Count'], ascending=False).head(10)
# Out:
#          Genre  Count
# 77       drama   8581
# 54      comedy   6849
# 3       action   5203
# 252   thriller   2882
# 199    romance   2143
# 62       crime   1552
# 146    musical    922
# 9    animation    747
# 44    children    637
# 147    mystery    461

# %%
genres['Count']=1
genres[['Genre','Count']].groupby(['Genre'], as_index=False).sum().sort_values(['Count'], ascending=False).head(10)
# Out:
#          Genre  Count
# 77       drama   8581
# 54      comedy   6849
# 3       action   5203
# 252   thriller   2882
# 199    romance   2143
# 62       crime   1552
# 146    musical    922
# 9    animation    747
# 44    children    637
# 147    mystery    461

# %%
#Genre selection/identification
genres=genres[['Genre','Count']].groupby(['Genre'], as_index=False).sum().sort_values(['Count'], ascending=False)
genres = genres[genres['Genre']!='']
genres.head(25)
# Out:
#            Genre  Count
# 77         drama   8581
# 54        comedy   6849
# 3         action   5203
# 252     thriller   2882
# 199      romance   2143
# 62         crime   1552
# 146      musical    922
# 9      animation    747
# 44      children    637
# 147      mystery    461
# 24     biography    452
# 87       fantasy    438
# 25         black    405
# 217        short    241
# 98       history    201
# 75   documentary    127
# 229       sports    100
# 210       series     86
# 5          adult     52
# 59       costume     48
# 173    political     38
# 84          epic     34
# 204       satire     33
# 73      disaster     30
# 248         teen     29

# %%
TotalCountGenres=sum(genres['Count'])
TotalCountGenres
# Out:
# 33107

# %%
genres['Frequency'] = genres['Count']/TotalCountGenres
genres['CumulativeFrequency'] = genres['Frequency'].cumsum()
genres.head(20)
# Out:
#            Genre  Count  Frequency  CumulativeFrequency
# 77         drama   8581   0.259190             0.259190
# 54        comedy   6849   0.206875             0.466065
# 3         action   5203   0.157157             0.623222
# 252     thriller   2882   0.087051             0.710273
# 199      romance   2143   0.064730             0.775002
# 62         crime   1552   0.046878             0.821881
# 146      musical    922   0.027849             0.849730
# 9      animation    747   0.022563             0.872293
# 44      children    637   0.019241             0.891534
# 147      mystery    461   0.013925             0.905458
# 24     biography    452   0.013653             0.919111
# 87       fantasy    438   0.013230             0.932341
# 25         black    405   0.012233             0.944574
# 217        short    241   0.007279             0.951853
# 98       history    201   0.006071             0.957924
# 75   documentary    127   0.003836             0.961760
# ...

# %%
np.array(genres[genres['CumulativeFrequency']<=.957]['Genre'])
# Out:
# array(['drama', 'comedy', 'action', 'thriller', 'romance', 'crime',
#        'musical', 'animation', 'children', 'mystery', 'biography',
#        'fantasy', 'black', 'short'], dtype=object)

# %%
genres[genres['CumulativeFrequency']<=.957][['Genre','Count']].plot(x='Genre', y='Count', kind='bar', legend=False, grid=True, figsize=(10,8), color = '#12ccf2' )
plt.title("Number of movies per genre")
plt.ylabel('# of Occurrences', fontsize=12)
plt.xlabel('Movie genres', fontsize=12)
plt.savefig('foo3.pdf')
plt.savefig('foo2_2.png')

# %%
mainGenres=np.array(genres[genres['CumulativeFrequency']<=.957]['Genre'])
arr1=np.array(['adult', 'romance', 'drama','and'])
arr1[np.in1d(arr1,mainGenres)] # genres not in the mainGenres array will be deleted
# Out:
# array(['romance', 'drama'], dtype='<U7')

# %%
mov_df2['GenreSplit'][10:12].apply(lambda x: x[np.in1d(x,mainGenres)])
# Out:
# 18    [comedy]
# 19    [action]
# Name: GenreSplit, dtype: object

# %%
mov_df2['GenreSplitMain'] = mov_df2['GenreSplit'].apply(lambda x: x[np.in1d(x,mainGenres)])
mov_df2[['GenreSplitMain','GenreSplit','Genre']][200:220]
# Out:
# <ipython-input-49-2e1853265627>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov_df2['GenreSplitMain'] = mov_df2['GenreSplit'].apply(lambda x: x[np.in1d(x,mainGenres)])
#         GenreSplitMain         GenreSplit            Genre
# 234           [action]           [action]        adventure
# 235            [drama]            [drama]            drama
# 236           [action]           [action]          western
# 237            [drama]            [drama]            drama
# 238           [comedy]           [comedy]           comedy
# 239    [comedy, drama]    [comedy, drama]     comedy drama
# 240           [action]           [action]          western
# 241            [drama]            [drama]            drama
# ...

# %%
#Introducing the bollywood dataset
mov_df_bolly = pd.read_csv(r'D:\Udemy Python and ML\Datasets\Movie\bollywood_full_1950-2019.csv')

# %%
mov_df_bolly
# Out:
#                                    title_x    imdb_id  \
# 0                 Uri: The Surgical Strike  tt8291224
# 1                            Battalion 609  tt9472208
# 2     The Accidental Prime Minister (film)  tt6986710
# 3                          Why Cheat India  tt8108208
# 4                          Evening Shadows  tt6028796
# ...                                    ...        ...
# 4325                   Samadhi (1950 film)  tt0268614
# 4326                   Sangram (1950 film)  tt0244182
# 4327                    Sargam (1950 film)  tt0269826
# 4328              Sheesh Mahal (1950 film)  tt0243555
# 4329                   Meena Bazaar (film)  tt0213081
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
mov_df_bolly.__doc__
# Out:
# "\n    Two-dimensional, size-mutable, potentially heterogeneous tabular data.\n\n    Data structure also contains labeled axes (rows and columns).\n    Arithmetic operations align on both row and column labels. Can be\n    thought of as a dict-like container for Series objects. The primary\n    pandas data structure.\n\n    Parameters\n    ----------\n    data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame\n        Dict can contain Series, arrays, constants, or list-like objects.\n\n        .. versionchanged:: 0.23.0\n           If data is a dict, column order follows insertion-order for\n           Python 3.6 and later.\n\n        .. versionchanged:: 0.25.0\n           If data is a list of dicts, column order follows insertion-order\n           for Python 3.6 and later.\n\n    index : Index or array-like\n        Index to use for resulting frame. Will default to RangeIndex if\n        no indexing information part of input data and no index provided.\n    columns
# ...

# %%
#Creating homogeneity in both tables
bollywood = mov_df_bolly.drop(['imdb_id','poster_path','is_adult','runtime','title_y','title_x','imdb_votes','imdb_rating'],axis=1)
bollywood
# Out:
#                                               wiki_link  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# 4325  https://en.wikipedia.org/wiki/Samadhi_(1950_film)
# 4326  https://en.wikipedia.org/wiki/Sangram_(1950_film)
# 4327   https://en.wikipedia.org/wiki/Sargam_(1950_film)
# 4328  https://en.wikipedia.org/wiki/Sheesh_Mahal_(19...
# 4329  https://en.wikipedia.org/wiki/Meena_Bazaar_(19...
#
#                      original_title year_of_release            genres  \
# 0          Uri: The Surgical Strike            2019  Action|Drama|War
# 1                     Battalion 609            2019               War
# 2     The Accidental Prime Minister            2019   Biography|Drama
# ...

# %%
bollywood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4330 entries, 0 to 4329
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   wiki_link         4330 non-null   object
#  1   original_title    4330 non-null   object
#  2   year_of_release   4330 non-null   object
#  3   genres            4330 non-null   object
#  4   story             4065 non-null   object
#  5   summary           4329 non-null   object
#  6   tagline           685 non-null    object
#  7   actors            4320 non-null   object
#  8   wins_nominations  1344 non-null   object
#  9   release_date      3049 non-null   object
# dtypes: object(10)
# memory usage: 169.2+ KB

# %%
bollywood['plot']= bollywood['story'] + bollywood['summary']
bollywood
# Out:
#                                               wiki_link  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# 4325  https://en.wikipedia.org/wiki/Samadhi_(1950_film)
# 4326  https://en.wikipedia.org/wiki/Sangram_(1950_film)
# 4327   https://en.wikipedia.org/wiki/Sargam_(1950_film)
# 4328  https://en.wikipedia.org/wiki/Sheesh_Mahal_(19...
# 4329  https://en.wikipedia.org/wiki/Meena_Bazaar_(19...
#
#                      original_title year_of_release            genres  \
# 0          Uri: The Surgical Strike            2019  Action|Drama|War
# 1                     Battalion 609            2019               War
# 2     The Accidental Prime Minister            2019   Biography|Drama
# ...

# %%
bollywood.drop(['summary','story'],axis=1)
# Out:
#                                               wiki_link  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# 4325  https://en.wikipedia.org/wiki/Samadhi_(1950_film)
# 4326  https://en.wikipedia.org/wiki/Sangram_(1950_film)
# 4327   https://en.wikipedia.org/wiki/Sargam_(1950_film)
# 4328  https://en.wikipedia.org/wiki/Sheesh_Mahal_(19...
# 4329  https://en.wikipedia.org/wiki/Meena_Bazaar_(19...
#
#                      original_title year_of_release            genres tagline  \
# 0          Uri: The Surgical Strike            2019  Action|Drama|War     NaN
# 1                     Battalion 609            2019               War     NaN
# ...

# %%
mov_df2.drop('Count',axis=1)
# Out:
#        Release Year                                              Title  \
# 6              1903                            The Great Train Robbery
# 7              1904                                    The Suburbanite
# 10             1906                           Dream of a Rarebit Fiend
# 11             1906  From Leadville to Aspen: A Hold-Up in the Rockies
# 12             1906                                Kathleen Mavourneen
# ...             ...                                                ...
# 34877          2013                                    Particle (film)
# 34882          2017                                 Çalgı Çengi İkimiz
# 34883          2017                                       Olanlar Oldu
# 34884          2017                                   Non-Transferable
# 34885          2017                                 İstanbul Kırmızısı
#
#       Origin/Ethnicity                                  Director  \
# ...

# %%
bollywood.rename(columns = {'wiki_link':'Wiki Page','original_title':'Title','year_of_release':'Release Year','genres':'Genre','actors':'Cast','plot':'Plot'}, inplace = True)
bollywood.drop(['story','summary','tagline','wins_nominations','release_date'],axis=1,inplace=True)
bollywood
# Out:
#                                               Wiki Page  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# 4325  https://en.wikipedia.org/wiki/Samadhi_(1950_film)
# 4326  https://en.wikipedia.org/wiki/Sangram_(1950_film)
# 4327   https://en.wikipedia.org/wiki/Sargam_(1950_film)
# 4328  https://en.wikipedia.org/wiki/Sheesh_Mahal_(19...
# 4329  https://en.wikipedia.org/wiki/Meena_Bazaar_(19...
#
#                               Title Release Year             Genre  \
# 0          Uri: The Surgical Strike         2019  Action|Drama|War
# 1                     Battalion 609         2019               War
# 2     The Accidental Prime Minister         2019   Biography|Drama
# ...

# %%
bollywood['Origin/Ethnicity']='Indian'
bollywood
# Out:
#                                               Wiki Page  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# 4325  https://en.wikipedia.org/wiki/Samadhi_(1950_film)
# 4326  https://en.wikipedia.org/wiki/Sangram_(1950_film)
# 4327   https://en.wikipedia.org/wiki/Sargam_(1950_film)
# 4328  https://en.wikipedia.org/wiki/Sheesh_Mahal_(19...
# 4329  https://en.wikipedia.org/wiki/Meena_Bazaar_(19...
#
#                               Title Release Year             Genre  \
# 0          Uri: The Surgical Strike         2019  Action|Drama|War
# 1                     Battalion 609         2019               War
# 2     The Accidental Prime Minister         2019   Biography|Drama
# ...

# %%
movies = pd.concat([mov_df2,bollywood],axis=0,ignore_index= True)

# %%
movies
# Out:
#       Release Year                                              Title  \
# 0             1903                            The Great Train Robbery
# 1             1904                                    The Suburbanite
# 2             1906                           Dream of a Rarebit Fiend
# 3             1906  From Leadville to Aspen: A Hold-Up in the Rockies
# 4             1906                                Kathleen Mavourneen
# ...            ...                                                ...
# 33128         1950                                            Samadhi
# 33129         1950                                            Sangram
# 33130         1950                                             Sargam
# 33131         1950                                       Sheesh Mahal
# 33132         1950                                       Meena Bazaar
#
#       Origin/Ethnicity                                  Director  \
# ...

# %%
movies['Cast'].fillna("Unavailable", inplace = True)

# %%
movies
# Out:
#       Release Year                                              Title  \
# 0             1903                            The Great Train Robbery
# 1             1904                                    The Suburbanite
# 2             1906                           Dream of a Rarebit Fiend
# 3             1906  From Leadville to Aspen: A Hold-Up in the Rockies
# 4             1906                                Kathleen Mavourneen
# ...            ...                                                ...
# 33128         1950                                            Samadhi
# 33129         1950                                            Sangram
# 33130         1950                                             Sargam
# 33131         1950                                       Sheesh Mahal
# 33132         1950                                       Meena Bazaar
#
#       Origin/Ethnicity                                  Director  \
# ...

# %%
movies['Director'].fillna("Unknown",inplace = True)

# %%
movies['Origin/Ethnicity'].value_counts()
# Out:
# American        16979
# Indian           4330
# British          3067
# Bollywood        2337
# Telugu            930
# Tamil             777
# Japanese          757
# Canadian          714
# Malayalam         546
# Hong Kong         476
# Chinese           457
# Australian        432
# Bengali           274
# Kannada           209
# Russian           152
# Marathi           140
# Filipino          128
# Bangladeshi        83
# South_Korean       79
# Punjabi            69
# Egyptian           67
# Malaysian          60
# Turkish            59
# Assamese            9
# Maldivian           2
# Name: Origin/Ethnicity, dtype: int64

# %%
movies.replace('Hindi','Bollywood',inplace = True)
# Out:
# c:\users\admin\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\missing.py:49: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask = arr == x

# %%
movies
# Out:
#       Release Year                                              Title  \
# 0             1903                            The Great Train Robbery
# 1             1904                                    The Suburbanite
# 2             1906                           Dream of a Rarebit Fiend
# 3             1906  From Leadville to Aspen: A Hold-Up in the Rockies
# 4             1906                                Kathleen Mavourneen
# ...            ...                                                ...
# 33128         1950                                            Samadhi
# 33129         1950                                            Sangram
# 33130         1950                                             Sargam
# 33131         1950                                       Sheesh Mahal
# 33132         1950                                       Meena Bazaar
#
#       Origin/Ethnicity                                  Director  \
# ...

# %%
stats = pd.DataFrame(movies['Origin/Ethnicity'].value_counts())

stats
# Out:
#               Origin/Ethnicity
# American                 16979
# Bollywood                 6667
# British                   3067
# Telugu                     930
# Tamil                      777
# Japanese                   757
# Canadian                   714
# Malayalam                  546
# Hong Kong                  476
# Chinese                    457
# Australian                 432
# Bengali                    274
# Kannada                    209
# Russian                    152
# Marathi                    140
# Filipino                   128
# Bangladeshi                 83
# South_Korean                79
# Punjabi                     69
# Egyptian                    67
# Malaysian                   60
# Turkish                     59
# Assamese                     9
# Maldivian                    2

# %%
stats.plot(kind='bar',figsize = (15,15),grid= True, color = '#12ccf2')
plt.title('Origin Count',fontsize = 15)
plt.xlabel('Origin',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.savefig('foo4.png')
plt.savefig('foo4_1.pdf')
